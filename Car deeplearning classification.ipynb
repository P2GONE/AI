# %%
from sklearn.datasets import load_breast_cancer
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.neighbors import KNeighborsClassifier
import seaborn as sns

# %%
dataset = pd.read_csv('C:/Users/charl/Downloads/car.data', )
#index = 0 -> 처음 인덱스를 포함하지 않겠다., 만약 테이블이 제대로 안되었다면 그때 지운다
dataset.head()
# Out:
#    vhigh vhigh.1  2 2.1  small   low  unacc
# 0  vhigh   vhigh  2   2  small   med  unacc
# 1  vhigh   vhigh  2   2  small  high  unacc
# 2  vhigh   vhigh  2   2    med   low  unacc
# 3  vhigh   vhigh  2   2    med   med  unacc
# 4  vhigh   vhigh  2   2    med  high  unacc

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
for i in dataset:
    dataset[i]=le.fit_transform(dataset[i])

# %%
dataset
# Out:
#       vhigh  vhigh.1  2  2.1  small  low  unacc
# 0         3        3  0    0      2    2      2
# 1         3        3  0    0      2    0      2
# 2         3        3  0    0      1    1      2
# 3         3        3  0    0      1    2      2
# 4         3        3  0    0      1    0      2
# ...     ...      ... ..  ...    ...  ...    ...
# 1722      1        1  3    2      1    2      1
# 1723      1        1  3    2      1    0      3
# 1724      1        1  3    2      0    1      2
# 1725      1        1  3    2      0    2      1
# 1726      1        1  3    2      0    0      3
#
# [1727 rows x 7 columns]

# %%
dataset.columns
# Out:
# Index(['vhigh', 'vhigh.1', '2', '2.1', 'small', 'low', 'unacc'], dtype='object')

# %%
#one hot
Y = pd.get_dummies(y1).values

# %%
dataset.isna().sum()
# Out:
# vhigh      0
# vhigh.1    0
# 2          0
# 2.1        0
# small      0
# low        0
# unacc      0
# dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(data, Y, test_size=0.2, random_state=0)

# %%
print("X train :", X_train.shape)
print("y train :", y_train.shape)
print("X test :", X_test.shape)
print("y test :", y_test.shape)
# Out:
# X train : (1381, 7)
# y train : (1381, 4)
# X test : (346, 7)
# y test : (346, 4)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
X=dataset.drop('unacc',axis=1)
y=dataset.unacc
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.25,random_state=0)
X
# Out:
#       vhigh  vhigh.1  2  2.1  small  low
# 0         3        3  0    0      2    2
# 1         3        3  0    0      2    0
# 2         3        3  0    0      1    1
# 3         3        3  0    0      1    2
# 4         3        3  0    0      1    0
# ...     ...      ... ..  ...    ...  ...
# 1722      1        1  3    2      1    2
# 1723      1        1  3    2      1    0
# 1724      1        1  3    2      0    1
# 1725      1        1  3    2      0    2
# 1726      1        1  3    2      0    0
#
# [1727 rows x 6 columns]

# %%
from sklearn.linear_model import SGDClassifier
model = SGDClassifier(random_state=3224)

# %%
#상관 관계 행렬
df_corr=dataset.corr()

#히트맵
plt.figure(figsize=(10,10))
sns.set(font_scale=0.8)
sns.heatmap(df_corr, annot=True, cbar=False)
plt.show()

# %%
data = dataset

# %%
X_train, X_test, y_train, y_test = train_test_split(data, Y, test_size=0.2, random_state=0)

# %%
print(X_train.shape)
# Out:
# (1381, 7)

# %%
#Defining the model 

from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import SGD,Adam


model = Sequential()

model.add(Dense(10,input_shape=(7,),activation='ReLU'))
model.add(Dense(10,activation='ReLU'))
model.add(Dense(10,activation='ReLU'))
model.add(Dense(10,activation='ReLU'))
model.add(Dense(4,activation='softmax'))

model.compile(Adam(lr=0.0045),'categorical_crossentropy',metrics=['accuracy'])

model.summary()
#print("X train :", X_train.shape)
#print("y train :", y_train.shape)
#print("X test :", X_test.shape)
#print("y test :", y_test.shape)
# X_train을 위, y_train을 아래로
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_20 (Dense)            (None, 10)                80
#
#  dense_21 (Dense)            (None, 10)                110
#
#  dense_22 (Dense)            (None, 10)                110
#
#  dense_23 (Dense)            (None, 10)                110
#
#  dense_24 (Dense)            (None, 4)                 44
#
# =================================================================
# Total params: 454
# Trainable params: 454
# Non-trainable params: 0
# _________________________________________________________________
# C:\Users\charl\anaconda3\lib\site-packages\keras\optimizers\legacy\adam.py:117: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)

# %%
dataset
# Out:
#       vhigh  vhigh.1  2  2.1  small  low  unacc
# 0         3        3  0    0      2    2      2
# 1         3        3  0    0      2    0      2
# 2         3        3  0    0      1    1      2
# 3         3        3  0    0      1    2      2
# 4         3        3  0    0      1    0      2
# ...     ...      ... ..  ...    ...  ...    ...
# 1722      1        1  3    2      1    2      1
# 1723      1        1  3    2      1    0      3
# 1724      1        1  3    2      0    1      2
# 1725      1        1  3    2      0    2      1
# 1726      1        1  3    2      0    0      3
#
# [1727 rows x 7 columns]

# %%
#fitting the model and predicting 

# fit network
model_history=model.fit(x=X_train, y=y_train, epochs=100, batch_size=32,validation_data= (X_test,y_test))
y_pred = model.predict(X_test)

y_test_class = np.argmax(y_test,axis=1)
y_pred_class = np.argmax(y_pred,axis=1)
# Out:
# Epoch 1/100
# 44/44 [==============================] - 2s 17ms/step - loss: 0.6925 - accuracy: 0.7907 - val_loss: 0.3934 - val_accuracy: 0.9133
# Epoch 2/100
# 44/44 [==============================] - 0s 6ms/step - loss: 0.2634 - accuracy: 0.9283 - val_loss: 0.2534 - val_accuracy: 0.9277
# Epoch 3/100
# 44/44 [==============================] - 0s 6ms/step - loss: 0.1745 - accuracy: 0.9544 - val_loss: 0.1978 - val_accuracy: 0.9509
# Epoch 4/100
# 44/44 [==============================] - 0s 6ms/step - loss: 0.1320 - accuracy: 0.9631 - val_loss: 0.1841 - val_accuracy: 0.9509
# Epoch 5/100
# 44/44 [==============================] - 0s 6ms/step - loss: 0.1093 - accuracy: 0.9616 - val_loss: 0.1290 - val_accuracy: 0.9509
# Epoch 6/100
# 44/44 [==============================] - 0s 6ms/step - loss: 0.0720 - accuracy: 0.9638 - val_loss: 0.0869 - val_accuracy: 0.9509
# Epoch 7/100
# 44/44 [==============================] - 0s 6ms/step - loss: 0.0470 - accuracy: 0.9855 - val_loss: 0.0507 - val_accuracy: 0.9884
# Epoch 8/100
# 44/44 [==============================] - 0s 6ms/step - loss: 0.0266 - accuracy: 0.9928 - val_loss: 0.0277 - val_accuracy: 0.9913
# Epoch 9/100
# 44/44 [==============================] - 0s 6ms/step - loss: 0.0215 - accuracy: 0.9935 - val_loss: 0.0166 - val_accuracy: 0.9971
# Epoch 10/100
# 44/44 [==============================] - 0s 6ms/step - loss: 0.0111 - accuracy: 0.9964 - val_loss: 0.0285 - val_accuracy: 0.9913
# Epoch 11/100
# 44/44 [==============================] - 0s 6ms/step - loss: 0.0123 - accuracy: 0.9964 - val_loss: 0.0136 - val_accuracy: 0.9971
# Epoch 12/100
# 44/44 [==============================] - 0s 6ms/step - loss: 0.0066 - accuracy: 0.9986 - val_loss: 0.0077 - val_accuracy: 1.0000
# Epoch 13/100
# 44/44 [==============================] - 0s 6ms/step - loss: 0.0045 - accuracy: 0.9993 - val_loss: 0.0035 - val_accuracy: 1.0000
# Epoch 14/100
# 44/44 [==============================] - 0s 6ms/step - loss: 0.0040 - accuracy: 0.9993 - val_loss: 0.0034 - val_accuracy: 1.0000
# Epoch 15/100
# 44/44 [==============================] - 0s 5ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.0026 - val_accuracy: 1.0000
# Epoch 16/100
# 44/44 [==============================] - 0s 6ms/step - loss: 8.5045e-04 - accuracy: 1.0000 - val_loss: 0.0016 - val_accuracy: 1.0000
# Epoch 17/100
# 44/44 [==============================] - 0s 6ms/step - loss: 6.8284e-04 - accuracy: 1.0000 - val_loss: 0.0014 - val_accuracy: 1.0000
# Epoch 18/100
# 44/44 [==============================] - 0s 6ms/step - loss: 6.2749e-04 - accuracy: 1.0000 - val_loss: 0.0012 - val_accuracy: 1.0000
# Epoch 19/100
# 44/44 [==============================] - 0s 5ms/step - loss: 4.8648e-04 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 20/100
# 44/44 [==============================] - 0s 6ms/step - loss: 4.4584e-04 - accuracy: 1.0000 - val_loss: 9.3647e-04 - val_accuracy: 1.0000
# Epoch 21/100
# 44/44 [==============================] - 0s 6ms/step - loss: 4.1975e-04 - accuracy: 1.0000 - val_loss: 0.0010 - val_accuracy: 1.0000
# Epoch 22/100
# 44/44 [==============================] - 0s 5ms/step - loss: 3.5314e-04 - accuracy: 1.0000 - val_loss: 8.2406e-04 - val_accuracy: 1.0000
# Epoch 23/100
# 44/44 [==============================] - 0s 5ms/step - loss: 3.0566e-04 - accuracy: 1.0000 - val_loss: 8.0669e-04 - val_accuracy: 1.0000
# Epoch 24/100
# 44/44 [==============================] - 0s 5ms/step - loss: 2.8822e-04 - accuracy: 1.0000 - val_loss: 7.4696e-04 - val_accuracy: 1.0000
# Epoch 25/100
# 44/44 [==============================] - 0s 5ms/step - loss: 2.5639e-04 - accuracy: 1.0000 - val_loss: 7.2630e-04 - val_accuracy: 1.0000
# Epoch 26/100
# 44/44 [==============================] - 0s 5ms/step - loss: 2.3169e-04 - accuracy: 1.0000 - val_loss: 6.0409e-04 - val_accuracy: 1.0000
# Epoch 27/100
# 44/44 [==============================] - 0s 5ms/step - loss: 2.1453e-04 - accuracy: 1.0000 - val_loss: 5.9403e-04 - val_accuracy: 1.0000
# Epoch 28/100
# 44/44 [==============================] - 0s 5ms/step - loss: 1.9694e-04 - accuracy: 1.0000 - val_loss: 6.3678e-04 - val_accuracy: 1.0000
# Epoch 29/100
# 44/44 [==============================] - 0s 6ms/step - loss: 1.7233e-04 - accuracy: 1.0000 - val_loss: 5.2277e-04 - val_accuracy: 1.0000
# Epoch 30/100
# 44/44 [==============================] - 0s 5ms/step - loss: 1.5829e-04 - accuracy: 1.0000 - val_loss: 4.5974e-04 - val_accuracy: 1.0000
# Epoch 31/100
# 44/44 [==============================] - 0s 5ms/step - loss: 1.4919e-04 - accuracy: 1.0000 - val_loss: 4.6768e-04 - val_accuracy: 1.0000
# Epoch 32/100
# 44/44 [==============================] - 0s 4ms/step - loss: 1.3867e-04 - accuracy: 1.0000 - val_loss: 4.4544e-04 - val_accuracy: 1.0000
# Epoch 33/100
# 44/44 [==============================] - 0s 5ms/step - loss: 1.2979e-04 - accuracy: 1.0000 - val_loss: 3.7093e-04 - val_accuracy: 1.0000
# Epoch 34/100
# 44/44 [==============================] - 0s 5ms/step - loss: 2.0389e-04 - accuracy: 1.0000 - val_loss: 8.4837e-04 - val_accuracy: 1.0000
# Epoch 35/100
# 44/44 [==============================] - 0s 5ms/step - loss: 1.6760e-04 - accuracy: 1.0000 - val_loss: 5.2373e-04 - val_accuracy: 1.0000
# Epoch 36/100
# 44/44 [==============================] - 0s 5ms/step - loss: 1.0767e-04 - accuracy: 1.0000 - val_loss: 3.4665e-04 - val_accuracy: 1.0000
# Epoch 37/100
# 44/44 [==============================] - 0s 5ms/step - loss: 8.7532e-05 - accuracy: 1.0000 - val_loss: 3.0401e-04 - val_accuracy: 1.0000
# Epoch 38/100
# 44/44 [==============================] - 0s 5ms/step - loss: 8.1566e-05 - accuracy: 1.0000 - val_loss: 3.2253e-04 - val_accuracy: 1.0000
# Epoch 39/100
#
-05 - val_accuracy: 1.0000
# Epoch 70/100
# 44/44 [==============================] - 0s 5ms/step - loss: 1.8067e-05 - accuracy: 1.0000 - val_loss: 9.0782e-05 - val_accuracy: 1.0000
# Epoch 71/100
# 44/44 [==============================] - 0s 6ms/step - loss: 1.6894e-05 - accuracy: 1.0000 - val_loss: 8.8284e-05 - val_accuracy: 1.0000
# Epoch 72/100
# 44/44 [==============================] - 0s 6ms/step - loss: 1.6681e-05 - accuracy: 1.0000 - val_loss: 8.6613e-05 - val_accuracy: 1.0000
# Epoch 73/100
# 44/44 [==============================] - 0s 6ms/step - loss: 1.6189e-05 - accuracy: 1.0000 - val_loss: 8.0713e-05 - val_accuracy: 1.0000
# Epoch 74/100
# 44/44 [==============================] - 0s 6ms/step - loss: 1.5569e-05 - accuracy: 1.0000 - val_loss: 8.0211e-05 - val_accuracy: 1.0000
# Epoch 75/100
# 44/44 [==============================] - 0s 6ms/step - loss: 1.5012e-05 - accuracy: 1.0000 - val_loss: 7.3835e-05 - val_accuracy: 1.0000
# Epoch 76/100
# 44/44 [==============================] - 0s 6ms/step - loss: 1.4474e-05 - accuracy: 1.0000 - val_loss: 7.2296e-05 - val_accuracy: 1.0000
# Epoch 77/100
# 44/44 [==============================] - 0s 5ms/step - loss: 1.3881e-05 - accuracy: 1.0000 - val_loss: 7.2639e-05 - val_accuracy: 1.0000
# Epoch 78/100
# 44/44 [==============================] - 0s 6ms/step - loss: 1.3339e-05 - accuracy: 1.0000 - val_loss: 6.8532e-05 - val_accuracy: 1.0000
# Epoch 79/100
# 44/44 [==============================] - 0s 6ms/step - loss: 1.3096e-05 - accuracy: 1.0000 - val_loss: 6.6148e-05 - val_accuracy: 1.0000
# Epoch 80/100
# 44/44 [==============================] - 0s 5ms/step - loss: 1.2437e-05 - accuracy: 1.0000 - val_loss: 6.4445e-05 - val_accuracy: 1.0000
# Epoch 81/100
# 44/44 [==============================] - 0s 5ms/step - loss: 1.2075e-05 - accuracy: 1.0000 - val_loss: 6.1006e-05 - val_accuracy: 1.0000
# Epoch 82/100
# 44/44 [==============================] - 0s 5ms/step - loss: 1.1890e-05 - accuracy: 1.0000 - val_loss: 5.9775e-05 - val_accuracy: 1.0000
# Epoch 83/100
# 44/44 [==============================] - 0s 5ms/step - loss: 1.1358e-05 - accuracy: 1.0000 - val_loss: 5.8850e-05 - val_accuracy: 1.0000
# Epoch 84/100
# 44/44 [==============================] - 0s 6ms/step - loss: 1.0860e-05 - accuracy: 1.0000 - val_loss: 5.6449e-05 - val_accuracy: 1.0000
# Epoch 85/100
# 44/44 [==============================] - 0s 5ms/step - loss: 1.0585e-05 - accuracy: 1.0000 - val_loss: 5.3457e-05 - val_accuracy: 1.0000
# Epoch 86/100
# 44/44 [==============================] - 0s 5ms/step - loss: 1.0286e-05 - accuracy: 1.0000 - val_loss: 5.3648e-05 - val_accuracy: 1.0000
# Epoch 87/100
# 44/44 [==============================] - 0s 5ms/step - loss: 1.0186e-05 - accuracy: 1.0000 - val_loss: 5.0317e-05 - val_accuracy: 1.0000
# Epoch 88/100
# 44/44 [==============================] - 0s 5ms/step - loss: 9.7112e-06 - accuracy: 1.0000 - val_loss: 4.7984e-05 - val_accuracy: 1.0000
# Epoch 89/100
# 44/44 [==============================] - 0s 5ms/step - loss: 9.2847e-06 - accuracy: 1.0000 - val_loss: 4.8205e-05 - val_accuracy: 1.0000
# Epoch 90/100
# 44/44 [==============================] - 0s 5ms/step - loss: 9.0634e-06 - accuracy: 1.0000 - val_loss: 4.4590e-05 - val_accuracy: 1.0000
# Epoch 91/100
# 44/44 [==============================] - 0s 5ms/step - loss: 8.6363e-06 - accuracy: 1.0000 - val_loss: 4.4765e-05 - val_accuracy: 1.0000
# Epoch 92/100
# 44/44 [==============================] - 0s 5ms/step - loss: 8.4327e-06 - accuracy: 1.0000 - val_loss: 4.3010e-05 - val_accuracy: 1.0000
# Epoch 93/100
# 44/44 [==============================] - 0s 5ms/step - loss: 8.0929e-06 - accuracy: 1.0000 - val_loss: 4.1087e-05 - val_accuracy: 1.0000
# Epoch 94/100
# 44/44 [==============================] - 0s 5ms/step - loss: 7.8777e-06 - accuracy: 1.0000 - val_loss: 4.0344e-05 - val_accuracy: 1.0000
# Epoch 95/100
# 44/44 [==============================] - 0s 5ms/step - loss: 7.6589e-06 - accuracy: 1.0000 - val_loss: 3.8809e-05 - val_accuracy: 1.0000
# Epoch 96/100
# 44/44 [==============================] - 0s 5ms/step - loss: 7.3505e-06 - accuracy: 1.0000 - val_loss: 3.8579e-05 - val_accuracy: 1.0000
# Epoch 97/100
# 44/44 [==============================] - 0s 5ms/step - loss: 7.0745e-06 - accuracy: 1.0000 - val_loss: 3.6931e-05 - val_accuracy: 1.0000
# Epoch 98/100
# 44/44 [==============================] - 0s 5ms/step - loss: 6.9714e-06 - accuracy: 1.0000 - val_loss: 3.5495e-05 - val_accuracy: 1.0000
# Epoch 99/100
# 44/44 [==============================] - 0s 4ms/step - loss: 6.7223e-06 - accuracy: 1.0000 - val_loss: 3.5422e-05 - val_accuracy: 1.0000
# Epoch 100/100
# 44/44 [==============================] - 0s 5ms/step - loss: 6.5511e-06 - accuracy: 1.0000 - val_loss: 3.3194e-05 - val_accuracy: 1.0000
# 11/11 [==============================] - 0s 2ms/step

# %%
import matplotlib.pyplot as plt
import seaborn as sns

loss =model_history.history['loss']
val_loss =model_history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
acc =model_history.history['accuracy']
val_acc =model_history.history['val_accuracy']
plt.plot(epochs, acc, 'y', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
#Accuracy of the predicted values
from sklearn.metrics import classification_report,confusion_matrix
print(classification_report(y_test_class,y_pred_class))
print(confusion_matrix(y_test_class,y_pred_class))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        77
#            1       1.00      1.00      1.00        14
#            2       1.00      1.00      1.00       239
#            3       1.00      1.00      1.00        16
#
#     accuracy                           1.00       346
#    macro avg       1.00      1.00      1.00       346
# weighted avg       1.00      1.00      1.00       346
#
# [[ 77   0   0   0]
#  [  0  14   0   0]
#  [  0   0 239   0]
#  [  0   0   0  16]]

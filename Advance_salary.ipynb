# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
 
dataset = pd.read_csv('C:/Salary_Data.csv', index_col=0)
dataset.head()
# Out:
#        YearsExperience  Salary
# index
# 1                  1.1   39343
# 2                  1.3   46205
# 3                  1.5   37731
# 4                  2.0   43525
# 5                  2.2   39891

# %%
dataset.columns
# Out:
# Index(['YearsExperience', 'Salary'], dtype='object')

# %%
dataset.head()
# Out:
#        YearsExperience  Salary
# index
# 1                  1.1   39343
# 2                  1.3   46205
# 3                  1.5   37731
# 4                  2.0   43525
# 5                  2.2   39891

# %%
dataset.columns
# Out:
# Index(['YearsExperience', 'Salary'], dtype='object')

# %%
dataset.isna().sum()
# Out:
# YearsExperience    0
# Salary             0
# dtype: int64

# %%
c = [i for i in range(1,len(y_test)+1,1)]
plt.plot(c,y_test-y_pred,color='green',linestyle='-')
plt.xlabel('index')
plt.ylabel('Error')
plt.title('Error Value')
plt.show()

# %%
plt.figure(figsize=(12,6))
plt.scatter(y_test,y_pred,color='r',linestyle='-')
plt.show()

# %%
plt.scatter(dataset['YearsExperience'], dataset['Salary'])
plt.xlabel('YearsExperience')
plt.ylabel('Salary')

plt.show()

# %%
c = [i for i in range (1,len(y_test)+1,1)]
plt.plot(c,y_test,color='r',linestyle='-')
plt.plot(c,y_pred,color='b',linestyle='-')
plt.xlabel('Salary')
plt.ylabel('index')
plt.title('Prediction')
plt.show()

# %%
y=dataset.Salary.values
x=dataset.drop('Salary',axis=1)

# %%
X = dataset['Salary']

y = dataset['YearsExperience']

# %%
X.head()
# Out:
# index
# 1    39343
# 2    46205
# 3    37731
# 4    43525
# 5    39891
# Name: Salary, dtype: int64

# %%
X = X.to_numpy()
y = y.to_numpy()

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.20,random_state=0)

# %%
# 훈련 세트와 테스트 세트를 2차원 배열로 바꿉니다
X_train = X_train.reshape(-1, 1)
X_test =  X_test.reshape(-1, 1)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = regressor.predict(X_test) 
y_pred
# Out:
# array([1.40423128, 9.96057197, 3.35987966, 3.98012845, 9.41258615,
#        8.65074235])

# %%
#plot for the TRAIN
 
plt.scatter(X_train, y_train, color='red') # plotting the observation line
 
plt.plot(X_train, regressor.predict(X_train), color='blue') # plotting the regression line
 
plt.title("Salary vs Experience (Training set)") # stating the title of the graph
 
plt.xlabel("Years of experience") # adding the name of x-axis
plt.ylabel("Salaries") # adding the name of y-axis
plt.show() # specifies end of graph

# %%
regressor.score(X_test, y_test)
# Out:
# 0.9895076299410532

# %%
from sklearn.metrics import mean_absolute_error

# %%
# 테스트 세트에 대한 예측을 만듭니다
y_prediction = regressor.predict(X_test)
# 테스트 세트에 대한 평균 절댓값 오차를 계산합니다
mae = mean_absolute_error(y_test, y_prediction)
print(mae)

#test 데이터 비율을 다르게 해서 mae를 낮췄습니다.
# Out:
# 0.23201950898476728

# %%
print(regressor.coef_, regressor.intercept_)
# Out:
# [0.00010107] -2.4091314766062712

# %%
print(regressor.predict([[10]]))
# Out:
# [-2.40812081]

# %%
# 훈련 세트의 산점도를 그립니다
plt.scatter(X_train, y_train)

# 15에서 50까지 1차 방정식 그래프를 그립니다
plt.plot([0, 30], [regressor.coef_+regressor.intercept_, 50*regressor.coef_+lr.intercept_])
# 50cm 농어 데이터
plt.scatter(50, 1241.8, marker='^')
plt.xlabel('length')
plt.ylabel('weight')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_26052\3562499553.py in <module>
#       3
#       4 # 15에서 50까지 1차 방정식 그래프를 그립니다
# ----> 5 plt.plot([0, 30], [regressor.coef_+regressor.intercept_, 50*regressor.coef_+lr.intercept_])
#       6 # 50cm 농어 데이터
#       7 plt.scatter(50, 1241.8, marker='^')
#
# NameError: name 'lr' is not defined
